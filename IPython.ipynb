# %% [markdown]
# # IPython -
#
#
# ---

# %% [markdown]
# IPython (Interactive Python) is a command shell for interactive computing in multiple programming languages, originally developed for Python: it provides an **interactive interface** to Python, a number of **syntactic additions** to the language, and a **kernel for Jupyter Notebook**, which is a web-based interactive computational environment for creating, executing, and visualizing notebooks.

# %%
ipython
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-0c8359920307> in <module>()
# ----> 1 ipython
#
# NameError: name 'ipython' is not defined
