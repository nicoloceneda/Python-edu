# %% [markdown]
# # Help and Documentation
#
# IPython provides tools to explore documentation and source code, and for autocompletion.

# %% [markdown]
# ## Accessing Documentation
#
# Every Python object contains the reference to a string, known as doctring, which in most cases will contain a concise summary of the object and how to use it. Python has a built-in **`help()`** function that can access this information and print the results.
